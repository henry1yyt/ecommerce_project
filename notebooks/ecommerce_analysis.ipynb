# %% [markdown]
# # 基于 AI 扩展数据的电商大促运营分析与退货风险预测
# 本 Notebook 用于在 Jupyter、和鲸或 Kaggle 中一键复现项目。完整逻辑位于项目根目录的 `analysis.py`。

# %%
from pathlib import Path
project_root = Path.cwd()
if project_root.name == 'notebooks':
    project_root = project_root.parent
project_root

# %%
# %cd $project_root
# %run analysis.py

# %% [markdown]
# ## 查看核心结果

# %%
import pandas as pd
display(pd.read_csv('outputs/tables/model_evaluation.csv'))
display(pd.read_csv('outputs/tables/risk_profile_test.csv'))
display(pd.read_csv('outputs/tables/rfm_cluster_summary.csv'))

# %% [markdown]
# 运行完成后，请打开 `report/电商大促运营分析与退货风险预测.html` 查看最终数据故事报告。
