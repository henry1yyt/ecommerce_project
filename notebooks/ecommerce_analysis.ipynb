# %% [markdown]
# # Online Retail II 全量分析
# 数据仅来自和鲸公开数据集，不使用 demo 或 AI 扩展数据。

# %%
from pathlib import Path
root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
# %cd $root
# %run analysis.py

# %%
import pandas as pd
pd.read_csv('outputs/tables/rfm_cluster_summary.csv')
